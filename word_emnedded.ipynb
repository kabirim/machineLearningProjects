# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D

documents = ['This book is intended for a two-semester course in Economics taught out of the social sciences or business school.',
             'Both were chasing their own piece of history. Barcelona were trying to become the first team to claim back-to-back',
             "From Alzheimer's to cancer, earwax can contain valuable indicators to a person's"]

# %%
tokenizer = Tokenizer(lower=True)
tokenizer.fit_on_texts(documents) # learn
input_dim = len(tokenizer.word_index) + 1 
tokenizer.word_counts
# Out:
# OrderedDict([('this', 1),
#              ('book', 1),
#              ('is', 1),
#              ('intended', 1),
#              ('for', 1),
#              ('a', 2),
#              ('two', 1),
#              ('semester', 1),
#              ('course', 1),
#              ('in', 1),
#              ('economics', 1),
#              ('taught', 1),
#              ('out', 1),
#              ('of', 2),
#              ('the', 2),
#              ('social', 1),
#              ('sciences', 1),
#              ('or', 1),
#              ('business', 1),
#              ('school', 1),
#              ('both', 1),
#              ('were', 2),
#              ('chasing', 1),
#              ('their', 1),
#              ('own', 1),
#              ('piece', 1),
#              ('history', 1),
#              ('barcelona', 1),
#              ('trying', 1),
#              ('to', 5),
#              ('become', 1),
#              ('first', 1),
#              ('team', 1),
#              ('claim', 1),
# ...

# %%
encode = tokenizer.texts_to_sequences(documents)

list_len= []
for seq in encode:
    list_len.append(len(seq))

padSequences = pad_sequences(encode,maxlen=max(list_len),padding='post')
padSequences
# Out:
# array([[ 7,  8,  9, 10, 11,  2, 12, 13, 14, 15, 16, 17, 18,  3,  4, 19,
#         20, 21, 22, 23,  0],
#        [24,  5, 25, 26, 27, 28,  3, 29, 30,  5, 31,  1, 32,  4, 33, 34,
#          1, 35,  6,  1,  6],
#        [36, 37,  1, 38, 39, 40, 41, 42, 43,  1,  2, 44,  0,  0,  0,  0,
#          0,  0,  0,  0,  0]])

# %%
model = Sequential()
model.add(Embedding(input_dim = input_dim,output_dim=50))
model.add(Conv1D(filters=50,kernel_size=5))

model.summary()

# pred = model.predict(padSequences)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_11 (Embedding)    (None, None, 50)          2250
#
#  conv1d_5 (Conv1D)           (None, None, 50)          12550
#
# ...
# Total params: 14800 (57.81 KB)
# Trainable params: 14800 (57.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pred.shape
# Out:
# (3, 21, 50)
